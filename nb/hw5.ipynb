# %%
cd ~/Desktop/workbench/fa21/cs285/hw/nb
# Out:
# /Users/gautam/Desktop/workbench/fa21/cs285/hw/nb

# %%
import glob
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
plt.rcParams.update({'font.size': 22})
np.random.seed(seed=1)


def set_size(width_pt, fraction=1, subplots=(1, 1)):
    """Set figure dimensions to sit nicely in our document.
  
    Source: https://jwalton.info/Matplotlib-latex-PGF/
    """
    # Width of figure (in pts)
    fig_width_pt = width_pt * fraction
    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio * (subplots[0] / subplots[1])

    return (fig_width_in, fig_height_in)

# %%
width, height = set_size(600 * 1.5, subplots=(1, 1))

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### Experiment 1

# %%
runs = glob.glob('hw5_logs/q1-1/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('env1_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('RND vs. epsilon-greedy (random) exploration')
ax.legend(frameon=False, loc='lower right')

# %% [markdown]
# ### Experiment 2

# %%
runs = glob.glob('hw5_logs/q1-2/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('alg_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('Count-based exploration by quantizing states to 1000 x 1000 grid')
ax.legend(frameon=False, loc='lower right')

# %% [markdown]
# ## Part 2
#
# ### Experiment 1

# %%
runs = glob.glob('hw5_logs/q2-1/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q2_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('CQL vs. DQN')
ax.legend(frameon=False, loc='lower right')

# %%
runs = glob.glob('hw5_logs/q2-1/*-Exploitation_Data_q-values.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    param_str = run.split('q2_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    line.set_label(param_str)
    
ax.set_ylabel('Exploitation Data Q-values')
ax.set_xlabel('Iteration')
ax.set_title('CQL vs. DQN')
ax.legend(frameon=False, loc='lower right')

# %% [markdown]
# ### Experiment 2

# %%
runs = glob.glob('hw5_logs/q2-2/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q2_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('Performance of DQN and CQL with varying exploration timescales')
ax.legend(frameon=False, loc='upper left')

# %% [markdown]
# ### Experiment 3

# %%
runs = glob.glob('hw5_logs/q2-3/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q2_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('Performance of CQL with varying alpha')
ax.legend(frameon=False, loc='upper left')

# %% [markdown]
# ## Part 3

# %%
runs = glob.glob('hw5_logs/q3/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q3_')[-1].split('_21')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('Supervised RND')
ax.legend(frameon=False, loc='lower right')

# %% [markdown]
# ## Part 4

# %%
runs = glob.glob('hw5_logs/q4/1/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q4_')[-1].split('_22')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('AWAC performance (Medium, Unsupervised)')
ax.legend(frameon=False, loc='lower right')

# %%
runs = glob.glob('hw5_logs/q4/2/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q4_')[-1].split('_22')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('AWAC performance (Medium, Supervised)')
ax.legend(frameon=False, loc='lower right')

# %%
runs = glob.glob('hw5_logs/q4/3/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q4_')[-1].split('_22')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('AWAC performance (Easy, Unsupervised)')
ax.legend(frameon=False, loc='lower right')

# %%
runs = glob.glob('hw5_logs/q4/4/*-Eval_AverageReturn.csv')

fig, ax = plt.subplots(1, 1, figsize=(width, height))

for run in runs:
    df = pd.read_csv(run)
    
    std_run = ''.join(run.split('-Eval_AverageReturn.csv') + ['-Eval_StdReturn.csv'])
    std_df = pd.read_csv(std_run)
    std = std_df['Value'].values
    
    param_str = run.split('q4_')[-1].split('_22')[0]
    steps = df['Step'].values
    values = df['Value'].values
    line, = ax.plot(steps, values)
    ax.fill_between(steps, values-std, values+std, alpha=0.3)
    line.set_label(param_str)
    
ax.set_ylabel('Average eval return')
ax.set_xlabel('Iteration')
ax.set_title('AWAC performance (Easy, Supervised)')
ax.legend(frameon=False, loc='lower right')
